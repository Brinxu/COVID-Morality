# %% [markdown]
# # Liberty scoring at a post level
# The approach we will use in this notebook is similar to the one used [here](https://github.com/oaraque/moral-foundations/blob/9d84f014fb257ce5d6cd77b48ed104edc911e31e/moralstrength/moralstrength.py#L46), where they average the annotations for the words in the sentence, if the word isn't found in our lexicon, it will be skipped.

# %% [markdown]
# To add more details about the used approach, I will give an example, suppose we have the sentence below :
# sentence = "I am feeling exhausted" the below function will actually transform this sentence into a set of tokens like ["I", "am", "feeling", "exhausted"] and then it will start looping over this list for each token we will get its lemmatized version which will be like ["i", "be", "feel", "exhausted"] and then for each word we will try to get its Liberty score from the lemmatized_liberty_lexicon dictionary in case it exist and sum its value into the sum variable which is initialised with 0 at the beginning, at the end we will count how many score we were able to find in our dictionary this will be recognized_words_no , hence we will divide the sum of values found by how many words were found, if a word wasn't found in the Libert dictionary it is ignored.

# %%
# load libraries
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import json
from nltk.tokenize import word_tokenize
import spacy
from nltk import word_tokenize
import string
from nltk.corpus import stopwords
import re
# Out:
# 2022-12-24 12:04:04.988962: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
try:
    nlp = spacy.load("en_core_web_sm")
    nlp_reduced = spacy.load("en_core_web_sm", disable=["tagger", "parser", "ner"])
except OSError as error:
    if "Can't find model 'en_core_web_sm'" in error.args[0]:
        print('Downloading files required by the Spacy language processing library (this is only required once)')
        spacy.cli.download('en_core_web_sm')
    nlp = spacy.load("en_core_web_sm")
    nlp_reduced = spacy.load("en_core_web_sm", disable=["tagger", "parser", "ner"])

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/brinxu/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/brinxu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/brinxu/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import json

with open('liberty_lexicon.json', 'r') as f:
    lemmatized_liberty_lexicon = json.load(f)

# %%
lemmatized_liberty_lexicon["freedom"]
# Out:
# 0.9795918367346939

# %%
def document_average_liberty(text):
    # initialize the sum of scores and how many token will be found in our lexicon 
    sum = 0
    recognized_words_no = 0

    # loop over each token in the text and get their score of liberty from the lexicon
    for token in nlp(text):
        try:
            # get the liberty score of the lemmatized token
            liberty_score = lemmatized_liberty_lexicon[token.lemma_]
            # check if there is a score in the dict
            if liberty_score:
                # then sum up with the old value
                sum += liberty_score
            # increment the number of words that were found in the dictionary 
            recognized_words_no += 1
        # this is a silent exception in case the word wasn't found in the dict
        except:
          # print(f"The word {token} was not found in the dictionary")
          continue
  
    if recognized_words_no == 0:
        # delete the below line if want value 0 instead of NaN
        return float('NaN')
    else:
        return sum/recognized_words_no

# %%
# test the function over a sample text
document_average_liberty("limiting freedom is")
# Out:
# 0.5782312925170069

# %% [markdown]
# Even though the token is doesn't exist in our dictionary but after lemmatization, it was transformed to its original verb be which allows us to get its Liberty score and contribute to the document scoring.
#
# Now our next step will be loading the tweets data and do some further data preprocessing to normalize the text data and then we can call our built-in function document_average_liberty to retrun the scores for each tweet.

# %%
# load posts data 
df_posts = pd.read_csv("covid_data_final.csv")
# Out:
# /var/folders/13/92pq4q957ljckd_vxp8nd8m80000gn/T/ipykernel_4731/54920089.py:2: DtypeWarning: Columns (32,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_posts = pd.read_csv("covid_data_final.csv")

# %%
df_posts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82389 entries, 0 to 82388
# Data columns (total 48 columns):
#  #   Column                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                              --------------  -----
#  0   Page Name                                                                                                           82389 non-null  object
#  1   User Name                                                                                                           82389 non-null  object
#  2   Facebook Id                                                                                                         82389 non-null  int64
#  3   Page Category                                                                                                       82389 non-null  object
#  4   Page Admin Top Country                                                                                              82389 non-null  object
#  5   Page Description                                                                                                    82389 non-null  object
#  6   Page Created                                                                                                        82389 non-null  object
#  7   Likes at Posting                                                                                                    82389 non-null  int64
#  8   Followers at Posting                                                                                                82389 non-null  float64
#  9   Post Created                                                                                                        82389 non-null  object
#  10  Post Created Date                                                                                                   82389 non-null  object
#  11  Post Created Time                                                                                                   82389 non-null  object
#  12  Type                                                                                                                82389 non-null  object
#  13  Total Interactions                                                                                                  82389 non-null  object
#  14  Likes                                                                                                               82389 non-null  int64
#  15  Comments                                                                                                            82389 non-null  int64
#  16  Shares                                                                                                              82389 non-null  int64
#  17  Love                                                                                                                82389 non-null  int64
#  18  Wow                                                                                                                 82389 non-null  int64
#  19  Haha                                                                                                                82389 non-null  int64
#  20  Sad                                                                                                                 82389 non-null  int64
#  21  Angry                                                                                                               82389 non-null  int64
#  22  Care                                                                                                                82389 non-null  int64
#  23  Is Video Owner?                                                                                                     82389 non-null  object
#  24  Post Views                                                                                                          82389 non-null  int64
#  25  Total Views                                                                                                         82389 non-null  int64
#  26  Total Views For All Crossposts                                                                                      82389 non-null  int64
#  27  URL                                                                                                                 82389 non-null  object
#  28  Message                                                                                                             82389 non-null  object
#  29  Link                                                                                                                82389 non-null  object
#  30  Link Text                                                                                                           82389 non-null  object
#  31  Description                                                                                                         82389 non-null  object
#  32  Overperforming Score (weighted  —  Likes 1x Shares 1x Comments 1x Love 1x Wow 1x Haha 1x Sad 1x Angry 1x Care 1x )  82389 non-null  object
#  33  LNC_category                                                                                                        47938 non-null  object
#  34  covid                                                                                                               82389 non-null  object
#  35  care_p                                                                                                              82389 non-null  float64
#  36  fairness_p                                                                                                          82389 non-null  float64
#  37  loyalty_p                                                                                                           82389 non-null  float64
#  38  authority_p                                                                                                         82389 non-null  float64
#  39  sanctity_p                                                                                                          82389 non-null  float64
#  40  care_sent                                                                                                           82389 non-null  float64
#  41  fairness_sent                                                                                                       82389 non-null  float64
#  42  loyalty_sent                                                                                                        82389 non-null  float64
#  43  authority_sent                                                                                                      82389 non-null  float64
#  44  sanctity_sent                                                                                                       82389 non-null  float64
#  45  moral_nonmoral_ratio                                                                                                82389 non-null  float64
#  46  f_var                                                                                                               82389 non-null  float64
#  47  sent_var                                                                                                            82389 non-null  float64
# dtypes: float64(14), int64(14), object(20)
# memory usage: 30.2+ MB

# %%
# get stopwords list
stoplist = stopwords.words('english')
# get list of punctuations
punctuations = string.punctuation + "’¶•@°©®™"

# %%
# the next step will be normalizing text data to be ready for scoring calculation
def preprocess_text(text):
    """
    @param text string
    @return text string
    
    This function preprocess a given raw text by normalizing it to lowercase removing the stop words,
    punctuations and lemmatization
    """
        
    #string to lowercase
    txt = text.lower()
    
    # keep only ascii characters
    txt = re.sub(r"[^a-zA-ZÀ-ÿ]", " ", txt)
    
    #punctuation removal and map it to space
    translator = str.maketrans(punctuations, " "*len(punctuations))
    s = txt.translate(translator)
    
    #remove digits 
    no_digits = ''.join([i for i in s if not i.isdigit()])
    cleaner = " ".join(no_digits.split())
    
    # the word_tokenize function will transform the text from a simple string to a list of token "a b c d" ==> ["a", "b", "c", "d"]
    word_tokens = word_tokenize(cleaner)
    # here we are interested on keeping only words that doesn’t appear on the stoplist variable we created above
    filtered_sentence = [w for w in word_tokens if not w in stoplist]
    # sometime the stopwords list isn't exhaustive and we may found meaningless words with only one character, it's better to drop them
    filtered_sentence = [w for w in filtered_sentence if len(w)>1 ]
    # the opposite of word_tokenize ["a", "b", "c", "d"] ==> "a b c d"
    filtered_sentence = " ".join(filtered_sentence)
    
    # a double layer lemmatization word block
    # filtered_sentence = " ".join([lemmatize_word(word) for word in word_tokenize(filtered_sentence)])
    filtered_sentence = " ".join([token.lemma_ for token in nlp(filtered_sentence)])
    
    return filtered_sentence

# %%
example_tweet = df_posts["Message"][9]
print("Post before preprocessing : \n {}\n".format(example_tweet))
clean_tweet = preprocess_text(example_tweet)
print("Post After preprocessing : \n {}".format(clean_tweet))
# Out:
# Post before preprocessing :
#  It's another sign that airlines see a recovery from the pandemic on the horizon
#
# Post After preprocessing :
#  another sign airline see recovery pandemic horizon

# %%
# !pip install --quiet mapply

# %% [markdown]
# In this step we will need to apply the function we have created before called preprocess_text to all the messages, the normal process will do this row by row, so in order to maximise the speed of this process we call mapply function which will run it in a parallel way instead of sequential way which is very slow.

# %%
# to parallelize the processing function over the whole dataframe
import mapply
# the value n_workers=-1 means we gonna use all the cores available in our CPU
mapply.init(n_workers=-1)

# %%
# convert the values in messages to string fromat
df_posts["Message"] = df_posts["Message"].astype(str)
# now let's apply this preprocessing function over all our text data in the dataframe
df_posts["clean_post"] = df_posts["Message"].mapply(preprocess_text)
# Out:
#   0%|                                                    | 0/40 [00:00<?, ?it/s]

# %%
df_posts.sample(5)
# Out:
#                 Page Name User Name      Facebook Id       Page Category  \
# 69232             Reuters   Reuters  114050161948682  MEDIA_NEWS_COMPANY
# 81214             Reuters   Reuters  114050161948682  MEDIA_NEWS_COMPANY
# 79315             Reuters   Reuters  114050161948682  MEDIA_NEWS_COMPANY
# 35310  The New York Times   nytimes       5281959998  MEDIA_NEWS_COMPANY
# 2420                  CNN       cnn       5550296508  MEDIA_NEWS_COMPANY
#
#       Page Admin Top Country  \
# 69232                     US
# 81214                     US
# 79315                     US
# 35310                     US
# 2420                      US
#
#                                         Page Description         Page Created  \
# 69232  Welcome to Reuters news on Facebook. We share ...  2010-04-16 17:16:47
# 81214  Welcome to Reuters news on Facebook. We share ...  2010-04-16 17:16:47
# 79315  Welcome to Reuters news on Facebook. We share ...  2010-04-16 17:16:47
# 35310  Welcome to The New York Times on Facebook - a ...  2007-10-29 23:03:34
# 2420   Instant breaking news alerts and the most talk...  2007-11-07 22:14:27
#
#        Likes at Posting  Followers at Posting             Post Created  ...  \
# 69232           4453778             4868378.0  2020-08-29 22:12:07 EDT  ...
# 81214           4239432             4286030.0  2020-02-23 06:48:31 EST  ...
# 79315           4269121             4331947.0  2020-03-23 10:49:43 EDT  ...
# 35310          17687192            17964640.0  2021-06-02 09:15:12 EDT  ...
# 2420           34004742            37292022.0  2020-11-19 09:13:01 EST  ...
#
#       sanctity_p care_sent fairness_sent loyalty_sent  authority_sent  \
# 69232   0.052078 -0.050607     -0.093808    -0.029321       -0.104793
# 81214   0.056791 -0.237856      0.010871     0.010495       -0.107358
# 79315   0.095366 -0.191624     -0.073602    -0.125628       -0.099619
# 35310   0.087273 -0.282908     -0.082825    -0.057915       -0.172957
# 2420    0.085698 -0.075863     -0.049757     0.063734        0.003463
#
#        sanctity_sent  moral_nonmoral_ratio     f_var  sent_var  \
# 69232      -0.075743              1.000000  0.000047  0.000959
# 81214      -0.143920              2.000000  0.000175  0.011320
# 79315      -0.198258              1.444444  0.000101  0.003070
# 35310      -0.133163              1.428571  0.000107  0.007846
# 2420       -0.069810              1.000000  0.000261  0.003472
#
#                                               clean_post
# 69232  victoria australia post new case coronavirus s...
# 81214  follow list international sport event affect o...
# 79315  india say shut domestic flight halt spread cor...
# 35310  crime emerge significant issue pandemic contex...
# 2420   year old michigan er doctor go run marathon ba...
#
# [5 rows x 49 columns]

# %% [markdown]
# Now that our dataframe has the cleaned text data, we are ready to call our document_average_liberty function to score the documents on it.

# %%
df_posts["Liberty/oppression"] = df_posts["clean_post"].mapply(document_average_liberty)
# Out:
#   0%|                                                    | 0/40 [00:00<?, ?it/s]

# %%
# Explore the results
df_posts.sample(5)
# Out:
#       Page Name User Name      Facebook Id                  Page Category  \
# 31133     MSNBC     msnbc  273864989376427             MEDIA_NEWS_COMPANY
# 66005   Reuters   Reuters  114050161948682             MEDIA_NEWS_COMPANY
# 77552   Reuters   Reuters  114050161948682             MEDIA_NEWS_COMPANY
# 27585     MSNBC     msnbc  273864989376427             MEDIA_NEWS_COMPANY
# 14394       NPR       NPR      10643211755  BROADCASTING_MEDIA_PRODUCTION
#
#       Page Admin Top Country  \
# 31133                     US
# 66005                     US
# 77552                     US
# 27585                     US
# 14394                     US
#
#                                         Page Description         Page Created  \
# 31133  The destination for in-depth analysis of daily...  2012-05-14 16:26:44
# 66005  Welcome to Reuters news on Facebook. We share ...  2010-04-16 17:16:47
# 77552  Welcome to Reuters news on Facebook. We share ...  2010-04-16 17:16:47
# 27585  The destination for in-depth analysis of daily...  2012-05-14 16:26:44
# 14394  NPR is an independent, nonprofit media organiz...  2008-02-21 00:53:35
#
#        Likes at Posting  Followers at Posting             Post Created  ...  \
# 31133           2355067             2380637.0  2020-05-02 01:01:10 EDT  ...
# 66005           4571126             4984939.0  2020-11-27 15:20:13 EST  ...
# 77552           4306970             4393287.0  2020-04-10 06:47:37 EDT  ...
# 27585           2402454             2458834.0  2020-10-10 18:15:51 EDT  ...
# 14394           6612554             7181657.0  2020-03-24 07:45:04 EDT  ...
#
#       care_sent fairness_sent loyalty_sent authority_sent  sanctity_sent  \
# 31133 -0.099867     -0.069057    -0.066499      -0.015203      -0.013154
# 66005 -0.012237      0.013245     0.043233       0.040750       0.014820
# 77552 -0.110028     -0.031900     0.011207      -0.098941       0.005719
# 27585 -0.090325     -0.004022     0.027030      -0.021750      -0.096039
# 14394 -0.054901     -0.035541    -0.023704      -0.027798      -0.063129
#
#        moral_nonmoral_ratio     f_var  sent_var  \
# 31133              1.142857  0.000082  0.001413
# 66005              1.333333  0.000189  0.000520
# 77552              0.666667  0.000141  0.003260
# 27585              1.900000  0.000070  0.002937
# 14394              0.538462  0.000157  0.000297
#
#                                               clean_post  Liberty/oppression
# 31133  dr fauci say state follow federal guideline be...            0.520408
# 66005  canada next week reveal breadth emergency spen...            0.468878
# 77552  china wuhan keep test resident coronavirus loc...            0.536892
# 27585  coronavirus case set new single day record sta...            0.510204
# 14394  president trump hail anti malarial possible ga...            0.506122
#
# [5 rows x 50 columns]

# %%
# View the top 20 scores
df_posts.sort_values(by="Liberty/oppression", ascending=False).head(20)
# Out:
#                      Page Name       User Name      Facebook Id  \
# 11990                      NPR             NPR      10643211755
# 15346          Washington Post  washingtonpost       6250307292
# 79901                  Reuters         Reuters  114050161948682
# 8303                 Daily Kos        dailykos      43179984254
# 52265  The Wall Street Journal             WSJ       8304333127
# 19516                USA TODAY        usatoday      13652355666
# 33750                    MSNBC           msnbc  273864989376427
# 82332                      NBC             nbc      89742860745
# 23054                USA TODAY        usatoday      13652355666
# 14375                      NPR             NPR      10643211755
# 2363                       CNN             cnn       5550296508
# 41527       The New York Times         nytimes       5281959998
# 58277  The Wall Street Journal             WSJ       8304333127
# 53967  The Wall Street Journal             WSJ       8304333127
# 17092          Washington Post  washingtonpost       6250307292
# 900                        CNN             cnn       5550296508
# 58110  The Wall Street Journal             WSJ       8304333127
# 16875          Washington Post  washingtonpost       6250307292
# 39172       The New York Times         nytimes       5281959998
# 19062                      CBS             CBS      47360808996
#
#                        Page Category Page Admin Top Country  \
# 11990  BROADCASTING_MEDIA_PRODUCTION                     US
# 15346  BROADCASTING_MEDIA_PRODUCTION                     US
# 79901             MEDIA_NEWS_COMPANY                     US
# 8303                       NEWS_SITE                     US
# 52265             MEDIA_NEWS_COMPANY                     US
# 19516             MEDIA_NEWS_COMPANY                     US
# 33750             MEDIA_NEWS_COMPANY                     US
# 82332                     TV_NETWORK                     US
# 23054             MEDIA_NEWS_COMPANY                     US
# 14375  BROADCASTING_MEDIA_PRODUCTION                     US
# 2363              MEDIA_NEWS_COMPANY                     US
# 41527             MEDIA_NEWS_COMPANY                     US
# 58277             MEDIA_NEWS_COMPANY                     US
# 53967             MEDIA_NEWS_COMPANY                     US
# 17092  BROADCASTING_MEDIA_PRODUCTION                     US
# 900               MEDIA_NEWS_COMPANY                     US
# 58110             MEDIA_NEWS_COMPANY                     US
# 16875  BROADCASTING_MEDIA_PRODUCTION                     US
# 39172             MEDIA_NEWS_COMPANY                     US
# 19062                     TV_NETWORK                     US
#
#                                         Page Description         Page Created  \
# 11990  NPR is an independent, nonprofit media organiz...  2008-02-21 00:53:35
# 15346  Our award-winning journalists have covered Was...  2007-11-07 18:26:05
# 79901  Welcome to Reuters news on Facebook. We share ...  2010-04-16 17:16:47
# 8303                    News you can do something about.  2009-01-10 01:42:46
# 52265  Breaking news, investigative reporting, busine...  2008-02-11 22:26:53
# 19516  We bring clarity to the news of the day, helpi...  2008-04-09 18:29:16
# 33750  The destination for in-depth analysis of daily...  2012-05-14 16:26:44
# 82332  America’s Most Watched Network. The official F...  2009-04-21 21:27:43
# 23054  We bring clarity to the news of the day, helpi...  2008-04-09 18:29:16
# 14375  NPR is an independent, nonprofit media organiz...  2008-02-21 00:53:35
# 2363   Instant breaking news alerts and the most talk...  2007-11-07 22:14:27
# 41527  Welcome to The New York Times on Facebook - a ...  2007-10-29 23:03:34
# 58277  Breaking news, investigative reporting, busine...  2008-02-11 22:26:53
# 53967  Breaking news, investigative reporting, busine...  2008-02-11 22:26:53
# 17092  Our award-winning journalists have covered Was...  2007-11-07 18:26:05
# 900    Instant breaking news alerts and the most talk...  2007-11-07 22:14:27
# 58110  Breaking news, investigative reporting, busine...  2008-02-11 22:26:53
# 16875  Our award-winning journalists have covered Was...  2007-11-07 18:26:05
# 39172  Welcome to The New York Times on Facebook - a ...  2007-10-29 23:03:34
# 19062  This is CBS. Watch full episodes for free on w...  2009-01-29 02:25:43
#
#        Likes at Posting  Followers at Posting             Post Created  ...  \
# 11990           6654070             7697756.0  2020-07-30 20:36:36 EDT  ...
# 15346           6623823             7005003.0  2021-06-01 09:00:48 EDT  ...
# 79901           4258046             4316801.0  2020-03-18 04:40:30 EDT  ...
# 8303            1291981             1230317.0  2021-05-05 23:35:57 EDT  ...
# 52265           6565735             6766909.0  2021-06-02 11:30:55 EDT  ...
# 19516           8454194             9041160.0  2021-03-11 11:03:46 EST  ...
# 33750           2325559             2336835.0  2020-03-18 00:33:17 EDT  ...
# 82332           3030100             3255731.0  2020-09-11 17:14:36 EDT  ...
# 23054           8043243             8245757.0  2020-02-02 13:51:22 EST  ...
# 14375           6612554             7181657.0  2020-03-24 19:11:05 EDT  ...
# 2363           34014289            37313450.0  2020-11-23 06:30:14 EST  ...
# 41527          17230730            17205574.0  2020-05-03 18:55:08 EDT  ...
# 58277           6449115             6486277.0  2020-04-12 20:31:24 EDT  ...
# 53967           6598953             6740403.0  2021-01-23 10:01:07 EST  ...
# 17092           6480266             6965293.0  2020-08-26 09:31:14 EDT  ...
# 900            34356909            37946814.0  2021-03-23 19:01:23 EDT  ...
# 58110           6458217             6499041.0  2020-04-19 12:30:14 EDT  ...
# 16875           6492341             6761376.0  2020-10-04 21:00:04 EDT  ...
# 39172          17438238            17516369.0  2020-10-02 10:25:08 EDT  ...
# 19062           1584256             1957046.0  2021-06-15 11:26:37 EDT  ...
#
#       care_sent fairness_sent loyalty_sent authority_sent  sanctity_sent  \
# 11990  0.172398      0.204521     0.168465       0.145440       0.099991
# 15346 -0.095622     -0.013458     0.018570       0.008436      -0.032978
# 79901 -0.027828     -0.107975    -0.114024      -0.120254      -0.103167
# 8303  -0.193133     -0.177365     0.040152      -0.067462      -0.111529
# 52265 -0.104178     -0.077201    -0.061670      -0.005496      -0.057586
# 19516  0.024818     -0.038912     0.113412       0.166020       0.009502
# 33750 -0.093369     -0.051603     0.000963      -0.042207      -0.168220
# 82332  0.131403      0.156768     0.257800       0.214991       0.212431
# 23054 -0.061467      0.163779     0.226652       0.227953       0.212205
# 14375 -0.025490      0.023466    -0.051592      -0.080446       0.019548
# 2363  -0.004923     -0.115955    -0.084191      -0.030739       0.019418
# 41527 -0.225541     -0.141413     0.061886      -0.011966      -0.087397
# 58277 -0.002236     -0.125102     0.056946       0.075866       0.030497
# 53967 -0.205094     -0.218271    -0.166263      -0.028343      -0.046757
# 17092 -0.131863     -0.074648    -0.098568      -0.146275      -0.177087
# 900   -0.050494      0.035273     0.087044       0.059521      -0.001373
# 58110 -0.126650     -0.070176    -0.040072      -0.164011      -0.048051
# 16875 -0.264903      0.012997     0.107268      -0.083562      -0.054503
# 39172 -0.267289     -0.197233    -0.194229      -0.196226      -0.186537
# 19062 -0.105921     -0.033917     0.003375       0.024413      -0.049749
#
#        moral_nonmoral_ratio     f_var  sent_var  \
# 11990              0.555556  0.000191  0.001501
# 15346              1.250000  0.000326  0.002045
# 79901              1.000000  0.000870  0.001437
# 8303               0.166667  0.000400  0.008869
# 52265              1.571429  0.000700  0.001305
# 19516              0.400000  0.001446  0.006884
# 33750              1.333333  0.000682  0.004084
# 82332              0.272727  0.000785  0.002538
# 23054              0.500000  0.000410  0.015164
# 14375              0.636364  0.000822  0.002023
# 2363               0.714286  0.000040  0.003129
# 41527              1.000000  0.000303  0.012441
# 58277              1.000000  0.000075  0.006331
# 53967              0.857143  0.000098  0.007992
# 17092              2.333333  0.000521  0.001611
# 900                1.000000  0.000308  0.002884
# 58110              0.833333  0.002449  0.002867
# 16875              0.750000  0.000573  0.018955
# 39172              1.555556  0.000783  0.001105
# 19062              0.846154  0.000109  0.002554
#
#                                               clean_post  Liberty/oppression
# 11990  listen billie eilish new song future write rec...            0.979592
# 15346  anthony fauci pandemic email march april obtai...            0.979592
# 79901  china expel american journalist three newspape...            0.979592
# 8303   news roundup vaccine patent waiver mcconnell v...            0.938776
# 52265  oil rich country venezuela lack vaccine perfor...            0.918367
# 19516  heartbreaking heartwarming moment year life pa...            0.877551
# 33750  fundamental quality health crisis living depen...            0.877551
# 82332  connect brand new comedy tackle love life lock...            0.877551
# 23054  life like epicenter coronavirus outbreak http ...            0.877551
# 14375  tony award win american playwright terrence mc...            0.877551
# 2363   coronavirus app dog concern privacy particular...            0.877551
# 41527    life across look different coronavirus shutdown            0.877551
# 58277  life hack weather pandemic read advice submit ...            0.877551
# 53967  essay china rise challenge covid economic cris...            0.877551
# 17092  coronavirus pandemic black life matter woman s...            0.877551
# 900    life single parent challenging begin add pande...            0.877551
# 58110  family rv nomad hit road life coronavirus stra...            0.877551
# 16875    stage novel coronavirus pandemic mask fact life            0.877551
# 39172  france choy spend half life imprison massachus...            0.877551
# 19062  tony nominee nick cordero lose battle covid la...            0.877551
#
# [20 rows x 50 columns]

# %%
df_posts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82389 entries, 0 to 82388
# Data columns (total 50 columns):
#  #   Column                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                              --------------  -----
#  0   Page Name                                                                                                           82389 non-null  object
#  1   User Name                                                                                                           82389 non-null  object
#  2   Facebook Id                                                                                                         82389 non-null  int64
#  3   Page Category                                                                                                       82389 non-null  object
#  4   Page Admin Top Country                                                                                              82389 non-null  object
#  5   Page Description                                                                                                    82389 non-null  object
#  6   Page Created                                                                                                        82389 non-null  object
#  7   Likes at Posting                                                                                                    82389 non-null  int64
#  8   Followers at Posting                                                                                                82389 non-null  float64
#  9   Post Created                                                                                                        82389 non-null  object
#  10  Post Created Date                                                                                                   82389 non-null  object
#  11  Post Created Time                                                                                                   82389 non-null  object
#  12  Type                                                                                                                82389 non-null  object
#  13  Total Interactions                                                                                                  82389 non-null  object
#  14  Likes                                                                                                               82389 non-null  int64
#  15  Comments                                                                                                            82389 non-null  int64
#  16  Shares                                                                                                              82389 non-null  int64
#  17  Love                                                                                                                82389 non-null  int64
#  18  Wow                                                                                                                 82389 non-null  int64
#  19  Haha                                                                                                                82389 non-null  int64
#  20  Sad                                                                                                                 82389 non-null  int64
#  21  Angry                                                                                                               82389 non-null  int64
#  22  Care                                                                                                                82389 non-null  int64
#  23  Is Video Owner?                                                                                                     82389 non-null  object
#  24  Post Views                                                                                                          82389 non-null  int64
#  25  Total Views                                                                                                         82389 non-null  int64
#  26  Total Views For All Crossposts                                                                                      82389 non-null  int64
#  27  URL                                                                                                                 82389 non-null  object
#  28  Message                                                                                                             82389 non-null  object
#  29  Link                                                                                                                82389 non-null  object
#  30  Link Text                                                                                                           82389 non-null  object
#  31  Description                                                                                                         82389 non-null  object
#  32  Overperforming Score (weighted  —  Likes 1x Shares 1x Comments 1x Love 1x Wow 1x Haha 1x Sad 1x Angry 1x Care 1x )  82389 non-null  object
#  33  LNC_category                                                                                                        47938 non-null  object
#  34  covid                                                                                                               82389 non-null  object
#  35  care_p                                                                                                              82389 non-null  float64
#  36  fairness_p                                                                                                          82389 non-null  float64
#  37  loyalty_p                                                                                                           82389 non-null  float64
#  38  authority_p                                                                                                         82389 non-null  float64
#  39  sanctity_p                                                                                                          82389 non-null  float64
#  40  care_sent                                                                                                           82389 non-null  float64
#  41  fairness_sent                                                                                                       82389 non-null  float64
#  42  loyalty_sent                                                                                                        82389 non-null  float64
#  43  authority_sent                                                                                                      82389 non-null  float64
#  44  sanctity_sent                                                                                                       82389 non-null  float64
#  45  moral_nonmoral_ratio                                                                                                82389 non-null  float64
#  46  f_var                                                                                                               82389 non-null  float64
#  47  sent_var                                                                                                            82389 non-null  float64
#  48  clean_post                                                                                                          82389 non-null  object
#  49  Liberty/oppression                                                                                                  77493 non-null  float64
# dtypes: float64(15), int64(14), object(21)
# memory usage: 31.4+ MB

# %% [markdown]
# As we can see from the metadata above, we have 79,786 of non null scores on a dataset of 84,385, which seeme like 94.5% of prediction scores are set while the other 5.5% is null.

# %%
df_posts.to_csv('covid_data_final_with_scores.csv', index=False)
