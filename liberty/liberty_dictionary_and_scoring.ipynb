# %% [markdown]
# # Liberty Dictionary and Scoring

# %% [markdown]
# ## Installing some required dependencies

# %%
# !pip install --quiet xlrd==1.2.0
# Out:
# WARNING: You are using pip version 21.3.1; however, version 22.0.4 is available.
# You should consider upgrading via the '/Users/brinxu/opt/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
# load libraries
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import json
from nltk.tokenize import word_tokenize
import spacy
from nltk import word_tokenize
import string
from nltk.corpus import stopwords
import re

# %%
try:
    nlp = spacy.load("en_core_web_sm")
    nlp_reduced = spacy.load("en_core_web_sm", disable=["tagger", "parser", "ner"])
except OSError as error:
    if "Can't find model 'en_core_web_sm'" in error.args[0]:
        print('Downloading files required by the Spacy language processing library (this is only required once)')
        spacy.cli.download('en_core_web_sm')
    nlp = spacy.load("en_core_web_sm")
    nlp_reduced = spacy.load("en_core_web_sm", disable=["tagger", "parser", "ner"])

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/brinxu/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/brinxu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/brinxu/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# read questionnaire data
data = pd.read_excel("questionnaire.xls")

# %%
# let's have a look on the metadata
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10538 entries, 0 to 10537
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Candidate Words      10527 non-null  object
#  1    Liberty/oppression  10524 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 164.8+ KB

# %%
data.sample(5)
# Out:
#      Candidate Words   Liberty/oppression
# 1004            help                  3.0
# 646     mistreatment                  3.0
# 8641           bring                  3.0
# 6213            flag                  7.0
# 3050      charitable                  3.0

# %% [markdown]
# ## Build Dictionary
# ### Data Preprocessing
# Beofore building teh dictionary of `Liberty/oppression `, we will prepare our dataset by first droping columns we don't need and then we will normalize annotated values for a scale between 0-1.

# %%
data.rename(columns={' Liberty/oppression': 'Liberty/oppression'}, inplace=True)

# %%
data.sample(5)
# Out:
#       Candidate Words  Liberty/oppression
# 8932   forthrightness                 2.0
# 9308         financed                 7.0
# 6893      disentangle                 0.0
# 2077              all                 1.0
# 10084         appoint                 4.0

# %% [markdown]
# Now that our dataframe is ready to be transformed into a dictionary of keys and values, where keys are `Candidate Words` and values are `Liberty/oppression` scores, but before that we shall average the scores given by annotators to each candidate word and then we normalize our values.

# %%
data["Candidate Words"].value_counts()
# Out:
# restrict      11
# choose        11
# tops          11
# disapprove    11
# merit         11
#               ..
# deduct        10
# make          10
# 5              1
# 1              1
# 4              1
# Name: Candidate Words, Length: 960, dtype: int64

# %% [markdown]
# The block above show that each word is mostly annotated 11 times, some of them 10 times except the last three values of `1`, `4` and `5` who are annotated only once and they don't have any pertinence as candidate words, so they should be deleted.
# ## Averaging scores by candidate words

# %%
# averaging Liberty/oppression scores by candidate words
data_avg = data.groupby("Candidate Words").mean().reset_index()

# %%
data_avg.sample(5)
# Out:
#      Candidate Words  Liberty/oppression
# 805            sharp            2.090909
# 783         sanction            3.272727
# 692         provided            3.454545
# 565  marginalization            4.545455
# 467     independence            3.454545

# %% [markdown]
# Let's explore how our `Liberty/oppression` is distributed now after averaging their values.

# %%
data_avg.describe()
# Out:
#        Liberty/oppression
# count          960.000000
# mean             3.333496
# std              0.676836
# min              1.000000
# 25%              2.900000
# 50%              3.272727
# 75%              3.818182
# max              5.454545

# %% [markdown]
# As we can see, after averaging our `Liberty/oppression` the scale of score values is now between `1` and `5.454545`. This scale won't be helpful when we will do average scores at the document level, that's why normalzation is a mandatory step. Normalization is a technique often applied as part of data preparation for machine learning. The goal of normalization is to change the values of numeric columns in the dataset to a common scale, without distorting differences in the ranges of values.

# %%
# original value of the word "truth"
data_avg[data_avg["Candidate Words"] == "truth"]
# Out:
#     Candidate Words  Liberty/oppression
# 881           truth            3.181818

# %% [markdown]
# The way the value will be transformed is using the `MinMaxScaler` function which subtracts the minimum value in the feature and then divides by the range. The range is the difference between the original maximum and original minimum.
#
# Max = 5.454545
# Min = 1.000000
#
# So by applying the `MinMaxScaler` formula which is <img src="https://i.stack.imgur.com/EuitP.png"><br/>
# we will get :

# %%
x_truth = (3.181818 - 1)/(5.454545 - 1)
print(x_truth)
# Out:
# 0.4897959275301966

# %%
# apply normalization techniques 
column = 'Liberty/oppression'
data_avg[column] = MinMaxScaler().fit_transform(np.array(data_avg[column]).reshape(-1,1))

# view normalized data  
data_avg.sample(5)
# Out:
#     Candidate Words  Liberty/oppression
# 957             you            0.551020
# 856           taxes            0.816327
# 322          equity            0.673469
# 57           arrest            0.489796
# 670           prime            0.428571

# %%
# View top 20 sample
data_avg.sort_values(by="Liberty/oppression", ascending=False).head(20)
# Out:
#     Candidate Words  Liberty/oppression
# 298    emancipation            1.000000
# 389         freedom            0.979592
# 541       liberated            0.959184
# 603     obstruction            0.938776
# 233      demobilize            0.918367
# 70        autonomic            0.918367
# 71       autonomous            0.918367
# 144          choose            0.918367
# 895      unenslaved            0.897959
# 543       liberties            0.897959
# 390        freedoms            0.897959
# 2                 5            0.897959
# 145        choosing            0.877551
# 590     nationalism            0.877551
# 734       rejection            0.877551
# 234       democracy            0.877551
# 546            life            0.877551
# 916           upset            0.877551
# 542      liberation            0.857143
# 740        religion            0.857143

# %%
# let's get a bit more insights about our normalization output 
data_avg.describe()
# Out:
#        Liberty/oppression
# count          960.000000
# mean             0.523846
# std              0.151943
# min              0.000000
# 25%              0.426531
# 50%              0.510204
# 75%              0.632653
# max              1.000000

# %% [markdown]
# As we can see from the table above our column has been transformed into a range of values where the min is 0 and the max is 1.
# Now that our dataset is well normalized, we can start building our dictionary.

# %% [markdown]
# We then created a loop to read the data from the dataframe where we averaged scores given by coders to each candidate word and create a new dictionary that we will be using later on when we want to get the Liberty Score for a given word, since dictionary format in python is the most switable format for such task, all you need to provide is the key which iw the candidate word and it retruns the Liberty score, without needing to loop over the dataframe.

# %%
# initialize an empty dict
liberty_lexicon = {}

# loop over our dataframe
for index, row in data_avg.iterrows():
  liberty_lexicon[row["Candidate Words"]] = row["Liberty/oppression"]

print(f"there is {len(liberty_lexicon)} elements in our dictionary for Liberty/oppression scores")
# Out:
# there is 960 elements in our dictionary for Liberty/oppression scores

# %%
# test our dictionary 
liberty_lexicon["power"]
# Out:
# 0.6326530612244899

# %%
# save the dictionary as a json file
with open("liberty_lexicon.json", "w") as f:
  json.dump(liberty_lexicon, f, indent=4)

# %% [markdown]
# Within the same way, we will save another version of our lexicon but in a very fine-grained version, where we will lemmatize the candidate words, so that both words banning and ban would have access to the same score since they share the same semantic behind.

# %%
def lemmatize_word(word):
  return ''.join([token.lemma_ for token in nlp(word)])

# %%
# test the function of lemmatization
lemmatize_word("banning")
# Out:
# 'ban'

# %%
# initialize an empty dict
lemmatized_liberty_lexicon = {}

# loop over our dataframe
for index, row in data_avg.iterrows():
  lemmatized_liberty_lexicon[lemmatize_word(str(row["Candidate Words"]))] = row["Liberty/oppression"]

print(f"there is {len(lemmatized_liberty_lexicon)} elements in our dictionary for Liberty/oppression scores")
# Out:
# there is 874 elements in our dictionary for Liberty/oppression scores

# %%
# save the dictionary as a json file
with open("lemmatized_liberty_lexicon.json", "w") as f:
  json.dump(lemmatized_liberty_lexicon, f, indent=4)

# %% [markdown]
# We can clearly see that after lemmatization process, our lexicon was reduced from 960 into 877, which means that there was a lot of words that shares the same root part of the word with just some different suffixes.

# %% [markdown]
# ## Liberty scoring at a post level
# The approach we will use in this notebook is similar to the one used [here](https://github.com/oaraque/moral-foundations/blob/9d84f014fb257ce5d6cd77b48ed104edc911e31e/moralstrength/moralstrength.py#L46), where they average the annotations for the words in the sentence, if the word isn't found in our lexicon, it will be skipped.

# %% [markdown]
# To add more details about the used approach, I will give an example, suppose we have the sentence below :
# sentence = "I am feeling exhausted" the below function will actually transform this sentence into a set of tokens like ["I", "am", "feeling", "exhausted"] and then it will start looping over this list for each token we will get its lemmatized version which will be like ["i", "be", "feel", "exhausted"] and then for each word we will try to get its Liberty score from the lemmatized_liberty_lexicon dictionary in case it exist and sum its value into the sum variable which is initialised with 0 at the beginning, at the end we will count how many score we were able to find in our dictionary this will be recognized_words_no , hence we will divide the sum of values found by how many words were found, if a word wasn't found in the Libert dictionary it is ignored.

# %%
def document_average_liberty(text):

  # initialize the sum of scores and how many token will be found in our lexicon 
  sum = 0
  recognized_words_no = 0

  # loop over each token in the text and get their score of liberty from the lexicon
  for token in nlp(text):
    try:
      # get the liberty score of the lemmatized token
      liberty_score = lemmatized_liberty_lexicon[token.lemma_]
      # check if there is a score in the dict
      if liberty_score:
        # then sum up with the old value
        sum += liberty_score
        # increment the number of words that were found in the dictionary 
        recognized_words_no += 1
    # this is a silent exception in case the word wasn't found in the dict
    except:
      # print(f"The word {token} was not found in the dictionary")
      continue
  
  if recognized_words_no == 0:
    return float('NaN')
  else:
    return sum/recognized_words_no

# %%
# test the function over a sample text
document_average_liberty("limiting freedom is")
# Out:
# 0.6938775510204082

# %% [markdown]
# Even though the token is doesn't exist in our dictionary but after lemmatization, it was transformed to its original verb be which allows us to get its Liberty score and contribute to the document scoring.
#
# Now our next step will be loading the tweets data and do some further data preprocessing to normalize the text data and then we can call our built-in function document_average_liberty to retrun the scores for each tweet.

# %%
# load posts data 
df_posts = pd.read_csv("covid_data_final.csv")
# Out:
# /Users/brinxu/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (32) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_posts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84385 entries, 0 to 84384
# Data columns (total 58 columns):
#  #   Column                                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                                --------------  -----
#  0   Page Name                                                                                                             84385 non-null  object
#  1   User Name                                                                                                             84385 non-null  object
#  2   Facebook Id                                                                                                           84385 non-null  int64
#  3   Page Category                                                                                                         84385 non-null  object
#  4   Page Admin Top Country                                                                                                84385 non-null  object
#  5   Page Description                                                                                                      84385 non-null  object
#  6   Page Created                                                                                                          84385 non-null  object
#  7   Likes at Posting                                                                                                      84385 non-null  float64
#  8   Followers at Posting                                                                                                  84385 non-null  float64
#  9   Post Created                                                                                                          84385 non-null  object
#  10  Post Created Date                                                                                                     84385 non-null  object
#  11  Post Created Time                                                                                                     84385 non-null  object
#  12  Type                                                                                                                  84385 non-null  object
#  13  Total Interactions                                                                                                    84385 non-null  object
#  14  Likes                                                                                                                 84385 non-null  int64
#  15  Comments                                                                                                              84385 non-null  int64
#  16  Shares                                                                                                                84385 non-null  int64
#  17  Love                                                                                                                  84385 non-null  int64
#  18  Wow                                                                                                                   84385 non-null  int64
#  19  Haha                                                                                                                  84385 non-null  int64
#  20  Sad                                                                                                                   84385 non-null  int64
#  21  Angry                                                                                                                 84385 non-null  int64
#  22  Care                                                                                                                  84385 non-null  int64
#  23  Is Video Owner?                                                                                                       84385 non-null  object
#  24  Post Views                                                                                                            84385 non-null  int64
#  25  Total Views                                                                                                           84385 non-null  int64
#  26  Total Views For All Crossposts                                                                                        84385 non-null  int64
#  27  URL                                                                                                                   84385 non-null  object
#  28  Message                                                                                                               84385 non-null  object
#  29  Link                                                                                                                  84385 non-null  object
#  30  Link Text                                                                                                             84385 non-null  object
#  31  Description                                                                                                           84385 non-null  object
#  32  Overperforming Score (weighted  —  Likes 1x Shares 1x Comments 1x Love 1x Wow 1x Haha 1x Sad 1x Angry 1x Care 1x )    84385 non-null  object
#  33  LNC_category                                                                                                          84385 non-null  object
#  34  ï»¿Page Name                                                                                                          0 non-null      float64
#  35  Video Share Status                                                                                                    0 non-null      float64
#  36  Video Length                                                                                                          0 non-null      float64
#  37  Final Link                                                                                                            0 non-null      float64
#  38  Image Text                                                                                                            0 non-null      float64
#  39  Sponsor Id                                                                                                            0 non-null      float64
#  40  Sponsor Name                                                                                                          0 non-null      float64
#  41  Sponsor Category                                                                                                      0 non-null      float64
#  42  Overperforming Score (weighted  â  Likes 1x Shares 1x Comments 1x Love 1x Wow 1x Haha 1x Sad 1x Angry 1x Care 1x )  0 non-null      float64
#  43  covid                                                                                                                 84385 non-null  object
#  44  PN                                                                                                                    61463 non-null  object
#  45  care_p                                                                                                                84385 non-null  float64
#  46  fairness_p                                                                                                            84385 non-null  float64
#  47  loyalty_p                                                                                                             84385 non-null  float64
#  48  authority_p                                                                                                           84385 non-null  float64
#  49  sanctity_p                                                                                                            84385 non-null  float64
#  50  care_sent                                                                                                             84385 non-null  float64
#  51  fairness_sent                                                                                                         84385 non-null  float64
#  52  loyalty_sent                                                                                                          84385 non-null  float64
#  53  authority_sent                                                                                                        84385 non-null  float64
#  54  sanctity_sent                                                                                                         84385 non-null  float64
#  55  moral_nonmoral_ratio                                                                                                  84385 non-null  float64
#  56  f_var                                                                                                                 84385 non-null  float64
#  57  sent_var                                                                                                              84385 non-null  float64
# dtypes: float64(24), int64(13), object(21)
# memory usage: 37.3+ MB

# %%
# get stopwords list
stoplist = stopwords.words('english')
# get list of punctuations
punctuations = string.punctuation + "’¶•@°©®™"

# %%
# the next step will be normalizing text data to be ready for scoring calculation
def preprocess_text(text):
    """
    @param text string
    @return text string
    
    This function preprocess a given raw text by normalizing it to lowercase removing the stop words,
    punctuations and lemmatization
    """
        
    #string to lowercase
    txt = text.lower()
    
    # keep only ascii characters
    txt = re.sub(r"[^a-zA-ZÀ-ÿ]", " ", txt)
    
    #punctuation removal and map it to space
    translator = str.maketrans(punctuations, " "*len(punctuations))
    s = txt.translate(translator)
    
    #remove digits 
    no_digits = ''.join([i for i in s if not i.isdigit()])
    cleaner = " ".join(no_digits.split())
    
    # the word_tokenize function will transform the text from a simple string to a list of token "a b c d" ==> ["a", "b", "c", "d"]
    word_tokens = word_tokenize(cleaner)
    # here we are interested on keeping only words that doesn’t appear on the stoplist variable we created above
    filtered_sentence = [w for w in word_tokens if not w in stoplist]
    # sometime the stopwords list isn't exhaustive and we may found meaningless words with only one character, it's better to drop them
    filtered_sentence = [w for w in filtered_sentence if len(w)>1 ]
    # the opposite of word_tokenize ["a", "b", "c", "d"] ==> "a b c d"
    filtered_sentence = " ".join(filtered_sentence)
    
    # a double layer lemmatization word block
    # filtered_sentence = " ".join([lemmatize_word(word) for word in word_tokenize(filtered_sentence)])
    filtered_sentence = " ".join([token.lemma_ for token in nlp(filtered_sentence)])
    
    return filtered_sentence

# %%
example_tweet = df_posts["Message"][9]
print("Post before preprocessing : \n {}\n".format(example_tweet))
clean_tweet = preprocess_text(example_tweet)
print("Post After preprocessing : \n {}".format(clean_tweet))
# Out:
# Post before preprocessing :
#  Millions of jobs and a shortage of applicants. Welcome to the new economy
#
# Post After preprocessing :
#  million job shortage applicant welcome new economy

# %%
# !pip install --quiet mapply
# Out:
# WARNING: You are using pip version 21.3.1; however, version 22.0.4 is available.
# You should consider upgrading via the '/Users/brinxu/opt/anaconda3/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# In this step we will need to apply the function we have created before called preprocess_text to all the messages, the normal process will do this row by row, so in order to maximise the speed of this process we call mapply function which will run it in a parallel way instead of sequential way which is very slow.

# %%
# to parallelize the processing function over the whole dataframe
import mapply
# the value n_workers=-1 means we gonna use all the cores available in our CPU
mapply.init(n_workers=-1)

# %%
# convert the values in messages to string fromat
df_posts["Message"] = df_posts["Message"].astype(str)
# now let's apply this preprocessing function over all our text data in the dataframe
df_posts["clean_post"] = df_posts["Message"].mapply(preprocess_text)
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]

# %%
df_posts.sample(5)
# Out:
#                      Page Name User Name      Facebook Id       Page Category  \
# 60049                  Reuters   Reuters  114050161948682  MEDIA_NEWS_COMPANY
# 24812                    MSNBC     msnbc  273864989376427  MEDIA_NEWS_COMPANY
# 50872  The Wall Street Journal       WSJ       8304333127  MEDIA_NEWS_COMPANY
# 42618                 Fox News   FoxNews      15704546335  MEDIA_NEWS_COMPANY
# 51196  The Wall Street Journal       WSJ       8304333127  MEDIA_NEWS_COMPANY
#
#       Page Admin Top Country  \
# 60049                     US
# 24812                     US
# 50872                     US
# 42618                     US
# 51196                     US
#
#                                         Page Description         Page Created  \
# 60049  Welcome to Reuters news on Facebook. We share ...  2010-04-16 17:16:47
# 24812  The destination for in-depth analysis of daily...  2012-05-14 16:26:44
# 50872  Breaking news, investigative reporting, busine...  2008-02-11 22:26:53
# 42618  Welcome to the official Fox News Facebook page...  2008-04-30 18:26:36
# 51196  Breaking news, investigative reporting, busine...  2008-02-11 22:26:53
#
#        Likes at Posting  Followers at Posting             Post Created  ...  \
# 60049         4644112.0             5137451.0  2021-01-30 11:48:18 EST  ...
# 24812         2437609.0             2512337.0  2020-11-11 23:41:10 EST  ...
# 50872         6575490.0             6702329.0  2020-12-27 19:00:29 EST  ...
# 42618        18775416.0            22411835.0  2021-01-28 17:29:34 EST  ...
# 51196         6572863.0             6692209.0  2020-12-07 10:00:15 EST  ...
#
#       sanctity_p care_sent fairness_sent loyalty_sent  authority_sent  \
# 60049   0.102580 -0.040991     -0.127771     0.003844       -0.177025
# 24812   0.087434 -0.168339     -0.073885    -0.126453       -0.079438
# 50872   0.090429 -0.102964     -0.207736    -0.096968       -0.036619
# 42618   0.068245 -0.019818     -0.014270     0.045541        0.065213
# 51196   0.098423 -0.088155     -0.065322    -0.117757       -0.040875
#
#        sanctity_sent  moral_nonmoral_ratio     f_var  sent_var  \
# 60049      -0.052653              1.000000  0.000468  0.005247
# 24812      -0.114194              1.125000  0.000223  0.001475
# 50872      -0.102668              0.571429  0.000612  0.003802
# 42618       0.106469              1.333333  0.000292  0.002888
# 51196      -0.107607              3.666667  0.000541  0.000981
#
#                                               clean_post
# 60049  dubai say saturday roll china sinopharm vaccin...
# 24812  government care people would fight we right ch...
# 50872  medical center overrun critical covid patient ...
# 42618  president biden thursday sign pair executive o...
# 51196  think soon quick public anxiety safety first c...
#
# [5 rows x 59 columns]

# %% [markdown]
# Now that our dataframe has the cleaned text data, we are ready to call our document_average_liberty function to score the documents on it.

# %%
df_posts["Liberty/oppression"] = df_posts["clean_post"].mapply(document_average_liberty)
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]

# %%
# let's explore the results
df_posts.sample(5)
# Out:
#                 Page Name User Name      Facebook Id       Page Category  \
# 38112  The New York Times   nytimes       5281959998  MEDIA_NEWS_COMPANY
# 61553             Reuters   Reuters  114050161948682  MEDIA_NEWS_COMPANY
# 4820                  CNN       cnn       5550296508  MEDIA_NEWS_COMPANY
# 22965               MSNBC     msnbc  273864989376427  MEDIA_NEWS_COMPANY
# 71358             Reuters   Reuters  114050161948682  MEDIA_NEWS_COMPANY
#
#       Page Admin Top Country  \
# 38112                     US
# 61553                     US
# 4820                      US
# 22965                     US
# 71358                     US
#
#                                         Page Description         Page Created  \
# 38112  Welcome to The New York Times on Facebook - a ...  2007-10-29 23:03:34
# 61553  Welcome to Reuters news on Facebook. We share ...  2010-04-16 17:16:47
# 4820   Instant breaking news alerts and the most talk...  2007-11-07 22:14:27
# 22965  The destination for in-depth analysis of daily...  2012-05-14 16:26:44
# 71358  Welcome to Reuters news on Facebook. We share ...  2010-04-16 17:16:47
#
#        Likes at Posting  Followers at Posting             Post Created  ...  \
# 38112        17296921.0            17295821.0  2020-05-27 15:26:09 EDT  ...
# 61553         4598408.0             5032372.0  2020-12-20 07:36:13 EST  ...
# 4820         33064976.0            35753556.0  2020-05-09 15:00:01 EDT  ...
# 22965         2475801.0             2573254.0  2021-01-27 07:32:08 EST  ...
# 71358         4341929.0             4445244.0  2020-05-08 02:57:11 EDT  ...
#
#       care_sent fairness_sent loyalty_sent authority_sent  sanctity_sent  \
# 38112  0.020178      0.037055     0.068215       0.006878       0.040835
# 61553 -0.049119      0.007700     0.053888      -0.006493       0.047233
# 4820  -0.025027     -0.045027     0.065662      -0.094205      -0.050249
# 22965 -0.112362     -0.052380    -0.138014      -0.149883      -0.018724
# 71358  0.003731      0.088134     0.061091       0.013507       0.054871
#
#        moral_nonmoral_ratio     f_var  sent_var  \
# 38112              4.333333  0.000304  0.000538
# 61553              1.083333  0.000152  0.001771
# 4820               0.750000  0.000137  0.003483
# 22965              1.500000  0.000636  0.003199
# 71358              1.750000  0.000023  0.001227
#
#                                               clean_post  Liberty/oppression
# 38112  education secretary betsy devos say force publ...            0.618076
# 61553  new national lockdown inevitable britain stop ...            0.551020
# 4820   uc hastings college law along san francisco bu...            0.619048
# 22965  georgia state lawmaker remove house chamber re...            0.816327
# 71358  green hydrogen time come long tout clean alter...            0.501134
#
# [5 rows x 60 columns]

# %%
# View the top 20 scores
df_posts.sort_values(by="Liberty/oppression", ascending=False).head(20)
# Out:
#                      Page Name        User Name      Facebook Id  \
# 11054                      NPR              NPR      10643211755
# 17596                      CBS              CBS      47360808996
# 39930       The New York Times          nytimes       5281959998
# 41567                 TheBlaze         TheBlaze  140738092630206
# 37472       The New York Times          nytimes       5281959998
# 54780  The Wall Street Journal              WSJ       8304333127
# 47271                Breitbart        Breitbart      95475020353
# 2055                       CNN              cnn       5550296508
# 38708       The New York Times          nytimes       5281959998
# 19132                USA TODAY         usatoday      13652355666
# 31797                    MSNBC            msnbc  273864989376427
# 46887                Breitbart        Breitbart      95475020353
# 16230          Washington Post   washingtonpost       6250307292
# 54615  The Wall Street Journal              WSJ       8304333127
# 21776                    MSNBC            msnbc  273864989376427
# 39830       The New York Times          nytimes       5281959998
# 81359                   Health  science channel      14482400667
# 29008                    MSNBC            msnbc  273864989376427
# 16319          Washington Post   washingtonpost       6250307292
# 18305                USA TODAY         usatoday      13652355666
#
#                        Page Category Page Admin Top Country  \
# 11054  BROADCASTING_MEDIA_PRODUCTION                     US
# 17596                     TV_NETWORK                     US
# 39930             MEDIA_NEWS_COMPANY                     US
# 41567             MEDIA_NEWS_COMPANY                     US
# 37472             MEDIA_NEWS_COMPANY                     US
# 54780             MEDIA_NEWS_COMPANY                     US
# 47271             MEDIA_NEWS_COMPANY                     US
# 2055              MEDIA_NEWS_COMPANY                     US
# 38708             MEDIA_NEWS_COMPANY                     US
# 19132             MEDIA_NEWS_COMPANY                     US
# 31797             MEDIA_NEWS_COMPANY                     US
# 46887             MEDIA_NEWS_COMPANY                     US
# 16230  BROADCASTING_MEDIA_PRODUCTION                     US
# 54615             MEDIA_NEWS_COMPANY                     US
# 21776             MEDIA_NEWS_COMPANY                     US
# 39830             MEDIA_NEWS_COMPANY                     US
# 81359                    HEALTH_SITE                     US
# 29008             MEDIA_NEWS_COMPANY                     US
# 16319  BROADCASTING_MEDIA_PRODUCTION                     US
# 18305             MEDIA_NEWS_COMPANY                     US
#
#                                         Page Description         Page Created  \
# 11054  NPR is an independent, nonprofit media organiz...  2008-02-21 00:53:35
# 17596  This is CBS. Watch full episodes for free on w...  2009-01-29 02:25:43
# 39930  Welcome to The New York Times on Facebook - a ...  2007-10-29 23:03:34
# 41567  News & entertainment for people who love America.  2010-08-18 23:57:09
# 37472  Welcome to The New York Times on Facebook - a ...  2007-10-29 23:03:34
# 54780  Breaking news, investigative reporting, busine...  2008-02-11 22:26:53
# 47271  Breitbart News (www.breitbart.com) is a conser...  2008-11-10 23:31:33
# 2055   Instant breaking news alerts and the most talk...  2007-11-07 22:14:27
# 38708  Welcome to The New York Times on Facebook - a ...  2007-10-29 23:03:34
# 19132  We bring clarity to the news of the day, helpi...  2008-04-09 18:29:16
# 31797  The destination for in-depth analysis of daily...  2012-05-14 16:26:44
# 46887  Breitbart News (www.breitbart.com) is a conser...  2008-11-10 23:31:33
# 16230  Our award-winning journalists have covered Was...  2007-11-07 18:26:05
# 54615  Breaking news, investigative reporting, busine...  2008-02-11 22:26:53
# 21776  The destination for in-depth analysis of daily...  2012-05-14 16:26:44
# 39830  Welcome to The New York Times on Facebook - a ...  2007-10-29 23:03:34
# 81359  Health provides whole-life advice and inspirat...  2008-04-23 04:18:42
# 29008  The destination for in-depth analysis of daily...  2012-05-14 16:26:44
# 16319  Our award-winning journalists have covered Was...  2007-11-07 18:26:05
# 18305  We bring clarity to the news of the day, helpi...  2008-04-09 18:29:16
#
#        Likes at Posting  Followers at Posting             Post Created  ...  \
# 11054         6654070.0             7697756.0  2020-07-30 20:36:36 EDT  ...
# 17596         1584256.0             1957046.0  2021-06-15 11:26:37 EDT  ...
# 39930        17058831.0            16965143.0  2020-03-24 15:35:07 EDT  ...
# 41567         2128162.0             2128833.0  2020-03-24 22:30:14 EDT  ...
# 37472        17377422.0            18043762.0  2020-07-09 04:55:05 EDT  ...
# 54780         6449115.0             6486277.0  2020-04-12 20:31:24 EDT  ...
# 47271         4375096.0             5274462.0  2020-08-24 02:46:39 EDT  ...
# 2055         34014289.0            37313450.0  2020-11-23 06:30:14 EST  ...
# 38708        17230730.0            17205574.0  2020-05-03 18:55:08 EDT  ...
# 19132         8252548.0             8729284.0  2020-10-16 15:11:10 EDT  ...
# 31797         2321561.0             2330487.0  2020-03-13 10:01:35 EDT  ...
# 46887         4541550.0             5198699.0  2021-01-08 00:49:34 EST  ...
# 16230         6438494.0             6611010.0  2020-05-31 09:00:14 EDT  ...
# 54615         6458217.0             6499041.0  2020-04-19 12:30:14 EDT  ...
# 21776         2481861.0             2587306.0  2021-04-24 11:49:08 EDT  ...
# 39830        17077629.0            16988520.0  2020-03-27 06:56:11 EDT  ...
# 81359         6521109.0             6644994.0  2020-07-18 13:30:02 EDT  ...
# 29008         2354295.0             2379446.0  2020-04-29 12:22:09 EDT  ...
# 16319         6429410.0             6594634.0  2020-05-20 06:35:19 EDT  ...
# 18305         8396197.0             8949177.0  2021-01-23 09:45:54 EST  ...
#
#       care_sent fairness_sent loyalty_sent authority_sent  sanctity_sent  \
# 11054  0.172398      0.204521     0.168465       0.145440       0.099991
# 17596 -0.105921     -0.033917     0.003375       0.024413      -0.049749
# 39930 -0.191699     -0.040353    -0.096786      -0.081401      -0.012155
# 41567 -0.279402     -0.169415    -0.234339      -0.120924      -0.158605
# 37472 -0.126714     -0.025842     0.039374      -0.122024      -0.008789
# 54780 -0.002236     -0.125102     0.056946       0.075866       0.030497
# 47271 -0.040229     -0.054519    -0.040611      -0.023919      -0.133633
# 2055  -0.004923     -0.115955    -0.084191      -0.030739       0.019418
# 38708 -0.225541     -0.141413     0.061886      -0.011966      -0.087397
# 19132 -0.122385     -0.099188    -0.247581      -0.279762      -0.202927
# 31797 -0.053747     -0.020537    -0.122076      -0.105994      -0.052069
# 46887 -0.331149     -0.238608    -0.181626      -0.254951      -0.141565
# 16230 -0.013006     -0.047757    -0.043696      -0.083339      -0.124093
# 54615 -0.126650     -0.070176    -0.040072      -0.164011      -0.048051
# 21776 -0.125709     -0.087385    -0.022911      -0.035071      -0.019981
# 39830 -0.119089     -0.136097    -0.207154      -0.102182      -0.177809
# 81359 -0.235239     -0.288940    -0.156131      -0.321544      -0.164978
# 29008 -0.373645     -0.393685    -0.254009      -0.308033      -0.331629
# 16319 -0.171487     -0.121400    -0.042049      -0.159189      -0.151169
# 18305  0.138952      0.117041     0.199827       0.113657       0.164534
#
#        moral_nonmoral_ratio     f_var  sent_var  \
# 11054              0.555556  0.000191  0.001501
# 17596              0.846154  0.000109  0.002554
# 39930              0.500000  0.000553  0.004709
# 41567              0.500000  0.000761  0.004027
# 37472              0.888889  0.000090  0.005334
# 54780              1.000000  0.000075  0.006331
# 47271              2.600000  0.000171  0.001878
# 2055               0.714286  0.000040  0.003129
# 38708              1.000000  0.000303  0.012441
# 19132              0.333333  0.000360  0.006089
# 31797              0.500000  0.000316  0.001759
# 46887              0.555556  0.000394  0.005272
# 16230              1.000000  0.000446  0.001812
# 54615              0.833333  0.002449  0.002867
# 21776              0.800000  0.000643  0.002163
# 39830              0.800000  0.000411  0.001866
# 81359              4.000000  0.001071  0.005377
# 29008              0.333333  0.000305  0.003049
# 16319              2.500000  0.000403  0.002707
# 18305              0.875000  0.000264  0.001293
#
#                                               clean_post  Liberty/oppression
# 11054  listen billie eilish new song future write rec...            0.897959
# 17596  tony nominee nick cordero lose battle covid la...            0.877551
# 39930  terrence mcnally tony award win playwright dra...            0.877551
# 41567  man florida survive covid credits malaria drug...            0.877551
# 37472  thousand serb demonstrate second consecutive n...            0.877551
# 54780  life hack weather pandemic read advice submit ...            0.877551
# 47271  official yale university tell student email la...            0.877551
# 2055   coronavirus app dog concern privacy particular...            0.877551
# 38708    life across look different coronavirus shutdown            0.877551
# 19132  preview upcoming appearance cbs sunday morning...            0.877551
# 31797  americans starting see massive disruption dail...            0.877551
# 46887  karen swallow prior blame pro life christians ...            0.877551
# 16230  art word nine illustrator grapple american lif...            0.877551
# 54615  family rv nomad hit road life coronavirus stra...            0.877551
# 21776  egg freezing boom pandemic woman opt wait fami...            0.877551
# 39830  economic fallout pandemic upend life tmyanmar ...            0.877551
# 81359  matter literally life death https www health c...            0.877551
# 29008  paintball life death historian jon meacham pre...            0.877551
# 16319          pandemic impact urban life vast far reach            0.877551
# 18305  year first know case covid confirm snohomish c...            0.877551
#
# [20 rows x 60 columns]

# %%
df_posts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84385 entries, 0 to 84384
# Data columns (total 60 columns):
#  #   Column                                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                                --------------  -----
#  0   Page Name                                                                                                             84385 non-null  object
#  1   User Name                                                                                                             84385 non-null  object
#  2   Facebook Id                                                                                                           84385 non-null  int64
#  3   Page Category                                                                                                         84385 non-null  object
#  4   Page Admin Top Country                                                                                                84385 non-null  object
#  5   Page Description                                                                                                      84385 non-null  object
#  6   Page Created                                                                                                          84385 non-null  object
#  7   Likes at Posting                                                                                                      84385 non-null  float64
#  8   Followers at Posting                                                                                                  84385 non-null  float64
#  9   Post Created                                                                                                          84385 non-null  object
#  10  Post Created Date                                                                                                     84385 non-null  object
#  11  Post Created Time                                                                                                     84385 non-null  object
#  12  Type                                                                                                                  84385 non-null  object
#  13  Total Interactions                                                                                                    84385 non-null  object
#  14  Likes                                                                                                                 84385 non-null  int64
#  15  Comments                                                                                                              84385 non-null  int64
#  16  Shares                                                                                                                84385 non-null  int64
#  17  Love                                                                                                                  84385 non-null  int64
#  18  Wow                                                                                                                   84385 non-null  int64
#  19  Haha                                                                                                                  84385 non-null  int64
#  20  Sad                                                                                                                   84385 non-null  int64
#  21  Angry                                                                                                                 84385 non-null  int64
#  22  Care                                                                                                                  84385 non-null  int64
#  23  Is Video Owner?                                                                                                       84385 non-null  object
#  24  Post Views                                                                                                            84385 non-null  int64
#  25  Total Views                                                                                                           84385 non-null  int64
#  26  Total Views For All Crossposts                                                                                        84385 non-null  int64
#  27  URL                                                                                                                   84385 non-null  object
#  28  Message                                                                                                               84385 non-null  object
#  29  Link                                                                                                                  84385 non-null  object
#  30  Link Text                                                                                                             84385 non-null  object
#  31  Description                                                                                                           84385 non-null  object
#  32  Overperforming Score (weighted  —  Likes 1x Shares 1x Comments 1x Love 1x Wow 1x Haha 1x Sad 1x Angry 1x Care 1x )    84385 non-null  object
#  33  LNC_category                                                                                                          84385 non-null  object
#  34  ï»¿Page Name                                                                                                          0 non-null      float64
#  35  Video Share Status                                                                                                    0 non-null      float64
#  36  Video Length                                                                                                          0 non-null      float64
#  37  Final Link                                                                                                            0 non-null      float64
#  38  Image Text                                                                                                            0 non-null      float64
#  39  Sponsor Id                                                                                                            0 non-null      float64
#  40  Sponsor Name                                                                                                          0 non-null      float64
#  41  Sponsor Category                                                                                                      0 non-null      float64
#  42  Overperforming Score (weighted  â  Likes 1x Shares 1x Comments 1x Love 1x Wow 1x Haha 1x Sad 1x Angry 1x Care 1x )  0 non-null      float64
#  43  covid                                                                                                                 84385 non-null  object
#  44  PN                                                                                                                    61463 non-null  object
#  45  care_p                                                                                                                84385 non-null  float64
#  46  fairness_p                                                                                                            84385 non-null  float64
#  47  loyalty_p                                                                                                             84385 non-null  float64
#  48  authority_p                                                                                                           84385 non-null  float64
#  49  sanctity_p                                                                                                            84385 non-null  float64
#  50  care_sent                                                                                                             84385 non-null  float64
#  51  fairness_sent                                                                                                         84385 non-null  float64
#  52  loyalty_sent                                                                                                          84385 non-null  float64
#  53  authority_sent                                                                                                        84385 non-null  float64
#  54  sanctity_sent                                                                                                         84385 non-null  float64
#  55  moral_nonmoral_ratio                                                                                                  84385 non-null  float64
#  56  f_var                                                                                                                 84385 non-null  float64
#  57  sent_var                                                                                                              84385 non-null  float64
#  58  clean_post                                                                                                            84385 non-null  object
#  59  Liberty/oppression                                                                                                    79786 non-null  float64
# dtypes: float64(25), int64(13), object(22)
# memory usage: 38.6+ MB

# %% [markdown]
# As we can see from the metadata above, we have 79,786 of non null scores on a dataset of 84,385, which seeme like 94.5% of prediction scores are set while the other 5.5% is null.

# %%
df_posts.to_csv('covid_data_final_with_scores.csv', index=False)
